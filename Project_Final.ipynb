# %% [markdown]
# <a href="https://colab.research.google.com/github/Twinklesangani/Data-Analyst-prolject/blob/main/Project_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv("/content/drive/MyDrive/data ana project/netflix_titles.csv")

# %%
data #to show data/run
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.head() #to show first 5 rows
#data.head(2) #to show only first two rows
#data.tail() #to show last 5 rows
#data.tail(2) #to show last two rows
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.info() #to print information of data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
#shape is used to show the no. of rows and col
data.shape
# Out:
# (8807, 12)

# %%
#size is used to show no. of total values in dataset
data.size
# Out:
# 105684

# %%
#col is used to show num of column
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#dtypesis used to show the data-types of each col
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data[data.duplicated()] #to check duplicate
#data.drop_duplicates(inplace=True) #inplace is used for permenet changes
#we will not use cause this data dosen't have any duplicate data
#data.shape
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data['title']
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
data['title'][100:113] #slice notation to select num range with 100 to 113
# Out:
# 100                     Tobot Galaxy Detectives
# 101                      Untold: Breaking Point
# 102    Countdown: Inspiration4 Mission to Space
# 103                              Shadow Parties
# 104                         Tayo the Little Bus
# 105                            Angamaly Diaries
# 106                                      Bunk'd
# 107                            A Champion Heart
# 108                                   Dive Club
# 109                            La casa de papel
# 110           Money Heist: From Tokyo to Berlin
# 111                                    Sharkdog
# 112                                       Worth
# Name: title, dtype: object

# %%
data.iloc[:, 0] #iloc will selsect all rows of first col
# Out:
# 0          s1
# 1          s2
# 2          s3
# 3          s4
# 4          s5
#         ...
# 8802    s8803
# 8803    s8804
# 8804    s8805
# 8805    s8806
# 8806    s8807
# Name: show_id, Length: 8807, dtype: object

# %%
data.iloc[[10,12,13,14],[1,2,3]] #this will selsect rows with index of 10,12,13,14 and col with index of 1,2,3
# Out:
#        type                                title             director
# 10  TV Show  Vendetta: Truth, Lies and The Mafia                  NaN
# 12    Movie                         Je Suis Karl  Christian Schwochow
# 13    Movie     Confessions of an Invisible Girl        Bruno Garotti
# 14  TV Show      Crime Stories: India Detectives                  NaN

# %%
data.iloc[:4,1] #this will give us values of :4 four rows and 1st col data
# Out:
# 0      Movie
# 1    TV Show
# 2    TV Show
# 3    TV Show
# Name: type, dtype: object

# %%
data.iloc[-5]
# Out:
# show_id                                                     s8803
# type                                                        Movie
# title                                                      Zodiac
# director                                            David Fincher
# cast            Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# country                                             United States
# date_added                                      November 20, 2019
# release_year                                                 2007
# rating                                                          R
# duration                                                  158 min
# listed_in                          Cult Movies, Dramas, Thrillers
# description     A political cartoonist, a crime reporter and a...
# Name: 8802, dtype: object

# %%
data.describe() #to show statistical data overview
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
data.groupby('show_id').release_year.max()
# Out:
# show_id
# s1       2020
# s10      2021
# s100     2021
# s1000    2021
# s1001    2020
#          ...
# s995     2020
# s996     2001
# s997     2021
# s998     2021
# s999     2021
# Name: release_year, Length: 8807, dtype: int64

# %% [markdown]
# NULL VALUES

# %%
data.isnull() #to check if there is any null values or not
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum() #count of null values
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data[data['title'].isin(['Kota Factory'])] #to show all records of particular item in any col
# Out:
#   show_id     type         title director  \
# 4      s5  TV Show  Kota Factory      NaN
#
#                                                 cast country  \
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
#
#            date_added  release_year rating   duration  \
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 4  In a city of coaching centers known to train I...

# %%
data[data['title'].str.contains('Kota Factory')]#to show all records of particular in any colum
# Out:
#   show_id     type         title director  \
# 4      s5  TV Show  Kota Factory      NaN
#
#                                                 cast country  \
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
#
#            date_added  release_year rating   duration  \
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 4  In a city of coaching centers known to train I...

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data['Data_Num']=pd.to_datetime(data['release_year'], format='%Y')

# %%
data.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
data['Data_Num'].dt.year.value_counts() #which will count occurrence of all individual year in date columan
# Out:
# Data_Num
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: count, Length: 74, dtype: int64

# %% [markdown]
# bar graph

# %%
#bar graph
data['Data_Num'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Data_Num'>

# %%
data.groupby('type').type.count() #to group all unique items of a columan and show their count
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
#CountPlot()
sns.countplot(data['type'])   #to show the count of all unique values of any column in the form of bar graph
# Out:
# <Axes: xlabel='count', ylabel='type'>

# %%
data['year'] = data['Data_Num'].dt.year #to create new year column; it will consider only year

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description   Data_Num  year
# 0  As her father nears the end of his life, filmm... 2020-01-01  2020
# 1  After crossing paths at a party, a Cape Town t... 2021-01-01  2021

# %%
#filtering data to show all the movies that released in year 2005
data[(data['type'] == 'Movie' ) & (data['year'] == 2005)]
# Out:
#      show_id   type                                             title  \
# 61       s62  Movie  Naruto the Movie 2: Legend of the Stone of Gelel
# 129     s130  Movie                                An Unfinished Life
# 151     s152  Movie                                         Initial D
# 202     s203  Movie                                 Kyaa Kool Hai Hum
# 578     s579  Movie                               Memoirs of a Geisha
# ...      ...    ...                                               ...
# 8346   s8347  Movie                                      The Holy Man
# 8668   s8669  Movie                                    V for Vendetta
# 8689   s8690  Movie                                        Waiting...
# 8767   s8768  Movie                           XXX: State of the Union
# 8793   s8794  Movie                              Yours, Mine and Ours
#
#                             director  \
# 61                Hirotsugu Kawasaki
# 129                  Lasse Hallström
# ...

# %%
data[(data['type']=='TV Show') & (data['country']=='India')] ['type']
# Out:
# 4       TV Show
# 39      TV Show
# 50      TV Show
# 66      TV Show
# 69      TV Show
#          ...
# 8173    TV Show
# 8235    TV Show
# 8321    TV Show
# 8349    TV Show
# 8775    TV Show
# Name: type, Length: 79, dtype: object

# %% [markdown]
# all the Records Where "Category is Movie and Type is comedie" or "Country is united Kingdom"[link text]

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description   Data_Num  year
# 0  As her father nears the end of his life, filmm... 2020-01-01  2020
# 1  After crossing paths at a party, a Cape Town t... 2021-01-01  2021

# %%
(data['type']=='Movie') & (data['listed_in']=='Comedies')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
data['director'].value_counts().head(10) #director give maximum num tv shows
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %% [markdown]
#  all the records, where or "Country is India"

# %%
data[(data['country']=='India')]
# Out:
#      show_id     type                          title                 director  \
# 4         s5  TV Show                   Kota Factory                      NaN
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem                      NaN
# 50       s51  TV Show                  Dharmakshetra                      NaN
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family                      NaN
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
# ...

# %% [markdown]
# movies/shows, Alia Bhatt was cast??

# %%
#filtering
#data[data['cast'] == 'Ama Qamata']
data[data['cast'].str.contains('Alia Bhatt', na=False)]
# Out:
#      show_id   type                      title          director  \
# 2728   s2729  Movie  Humpty Sharma Ki Dulhania  Shashank Khaitan
# 2733   s2734  Movie              Kapoor & Sons      Shakun Batra
# 2735   s2736  Movie                Magnificent        Vikas Bahl
# 4712   s4713  Movie                   2 States   Abhishek Varman
# 4726   s4727  Movie                    Highway        Imtiaz Ali
# 5515   s5516  Movie               Dear Zindagi      Gauri Shinde
# 5651   s5652  Movie                Udta Punjab  Abhishek Chaubey
#
#                                                    cast country  \
# 2728  Varun Dhawan, Alia Bhatt, Ashutosh Rana, Sidha...   India
# 2733  Rishi Kapoor, Sidharth Malhotra, Fawad Khan, A...   India
# 2735  Shahid Kapoor, Alia Bhatt, Pankaj Kapur, Sanja...   India
# 4712  Alia Bhatt, Arjun Kapoor, Ronit Roy, Amrita Si...   India
# 4726  Randeep Hooda, Alia Bhatt, Durgesh Kumar, Prad...   India
# ...

# %%
#to find result of perticur string str.contains()
#data[data['cast'].str.contains('Alia Bhatt', na=False)].count()]
data[data['cast'].str.contains('Alia Bhatt')].count() # as here is error is gating genrating because of NaN values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-7105e091c57d> in <cell line: 3>()
#       1 #to find result of perticur string str.contains()
#       2 #data[data['cast'].str.contains('Tom Cruise', na=False)].count()]
# ----> 3 data[data['cast'].str.contains('Tom Cruise')].count() # as here is error is gating genrating because of NaN values
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4090
#    4091         # Do we have a (boolean) 1d indexer?
# -> 4092         if com.is_bool_indexer(key):
#    4093             return self._getitem_bool_array(key)
#    4094
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     134                     # Don't raise on e.g. ["A", "B", np.nan], see
#     135                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# ...

# %%
data_new=data.dropna() #to remove NaN values

# %%
data_new.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description   Data_Num  year
# ...

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description   Data_Num  year
# 0  As her father nears the end of his life, filmm... 2020-01-01  2020
# 1  After crossing paths at a party, a Cape Town t... 2021-01-01  2021

# %%
data_new[data_new['cast'].str.contains('Alia Bhatt')]
# Out:
#      show_id   type                      title          director  \
# 2728   s2729  Movie  Humpty Sharma Ki Dulhania  Shashank Khaitan
# 2733   s2734  Movie              Kapoor & Sons      Shakun Batra
# 2735   s2736  Movie                Magnificent        Vikas Bahl
# 4712   s4713  Movie                   2 States   Abhishek Varman
# 4726   s4727  Movie                    Highway        Imtiaz Ali
# 5515   s5516  Movie               Dear Zindagi      Gauri Shinde
# 5651   s5652  Movie                Udta Punjab  Abhishek Chaubey
#
#                                                    cast country  \
# 2728  Varun Dhawan, Alia Bhatt, Ashutosh Rana, Sidha...   India
# 2733  Rishi Kapoor, Sidharth Malhotra, Fawad Khan, A...   India
# 2735  Shahid Kapoor, Alia Bhatt, Pankaj Kapur, Sanja...   India
# 4712  Alia Bhatt, Arjun Kapoor, Ronit Roy, Amrita Si...   India
# 4726  Randeep Hooda, Alia Bhatt, Durgesh Kumar, Prad...   India
# ...

# %% [markdown]
# the different Rating defined by Netflix

# %%
data['rating'].nunique() #to show num of unique values NUMBER ONLY
# Out:
# 17

# %%
data['rating'].unique() #to show string of unque values
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
#How many movies got 'TV-14' rating in canada??
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data[(data['type']=='Movie') & (data['rating']=='TV-14') ].shape
# Out:
# (1427, 14)

# %%
data[(data['type']=='Movie') & (data['rating']=='TV-14') & (data['country']=='Canada')].shape
# Out:
# (13, 14)

# %%
#how many TV shows got 'R' rating after years 2018??
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description   Data_Num  year
# 0  As her father nears the end of his life, filmm... 2020-01-01  2020
# 1  After crossing paths at a party, a Cape Town t... 2021-01-01  2021

# %%
data[(data['type']=='TV Show') & (data['rating']=='R')]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
# 7593   s7594  TV Show                                Nobel                NaN
#
#                                                    cast country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
#
#              date_added  release_year rating  duration  \
# 3893     April 25, 2019          2015      R  1 Season
# 7593  December 10, 2016          2016      R  1 Season
#
#                                             listed_in  \
# 3893                                         TV Shows
# 7593  International TV Shows, TV Dramas, TV Thrillers
#
#                                             description   Data_Num  year
# 3893  Trapped at a stagecoach stop as a storm rages ... 2015-01-01  2015
# ...

# %%
print(data[['year', 'Data_Num']].head(100))
# Out:
#     year   Data_Num
# 0   2020 2020-01-01
# 1   2021 2021-01-01
# 2   2021 2021-01-01
# 3   2021 2021-01-01
# 4   2021 2021-01-01
# ..   ...        ...
# 95  2021 2021-01-01
# 96  2018 2018-01-01
# 97  2021 2021-01-01
# 98  2021 2021-01-01
# 99  2021 2021-01-01
#
# [100 rows x 2 columns]

# %%
data['year'] = data['year'].astype(int)

# %%
data[(data['type']=='Tv Show') & (data['rating']=='R') & (data['year'] >=2019)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Data_Num, year]
# Index: []

# %% [markdown]
# the max duration of a movie/show on Netflix??

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description   Data_Num  year
# 0  As her father nears the end of his life, filmm... 2020-01-01  2020
# 1  After crossing paths at a party, a Cape Town t... 2021-01-01  2021

# %%
data.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
data.duration.dtypes
# Out:
# dtype('O')

# %%
#to create a single col from two dif. col we use str.split()
data[['min','unit']]= data['duration'].str.split(' ', expand=True)

# %%
time=data.groupby('duration').mean('duration')
print(time)
# Out:
#             release_year         year
# duration
# 1 Season     2016.585611  2016.585611
# 10 Seasons   2005.000000  2005.000000
# 10 min       2019.000000  2019.000000
# 100 min      2014.268519  2014.268519
# 101 min      2012.327586  2012.327586
# ...                  ...          ...
# 95 min       2013.978102  2013.978102
# 96 min       2013.769231  2013.769231
# 97 min       2014.006849  2014.006849
# 98 min       2013.966667  2013.966667
# 99 min       2013.957627  2013.957627
#
# [220 rows x 2 columns]
